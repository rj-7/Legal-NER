# %%
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('ggplot')
from matplotlib.ticker import MaxNLocator

# %%
spacy_maxout = [0.05,9.19,28.32,42.15,47.21,52.24,57.26,59.95,62.35,64.18,64.59,65.56,66.07,66.86,67.02,67.51,68.03,67.82,68.32,68.63,69.09,68.98,69.41,69.65,69.74,69.60,69.71,69.86,70.04,69.99,70.07,70.07,70.07,70.07,70.07,70.07]

# %%
epochs_maxout = [0,2,4,7,9,11,14,16,18,21,23,25,28,30,33,35,37,40,42,44,47,49,51,54,56,58,61,63,66,68,70,73,75,77,80,82]

# %%
spacy_mish = [ 0.05, 9.54,16.23,38.37,43.90,47.07,51.22,53.36,56.84,57.92,59.50,60.95,62.29,62.52,63.17,63.72,64.41,64.42,65.43,65.53,65.45,65.83,66.03,66.20,66.63,66.86,66.88,66.60,66.83,66.92,66.94,66.94,66.94,66.94,66.94,66.94]

# %%
epochs_mish = [ 0, 2, 4, 7, 9,11,14,16,18,21,23,25,28,30,33,35,37,40,42,44,47,49,51,54,56,58,61,63,66,68,70,73,75,77,80,82]

# %%
fig,ax = plt.subplots()

ax.plot(epochs_maxout, spacy_maxout, label="Encoder with Maxout activation")
ax.plot(epochs_mish, spacy_mish, label="Encoder with Mish activation")

ax.set_xlabel("Epochs")
ax.set_ylabel("F1-Score")

legend = ax.legend(loc='lower right', shadow=True, fontsize='x-large', fancybox=True)

plt.show()

# %%
epochs_transformer = [0,1,2,3,4]
spacy_transformer = [0.19,29.17,72.33,84.24,84.80]

# %%
fig,ax = plt.subplots()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax.plot(epochs_transformer, spacy_transformer)

ax.set_xlabel("Epochs")
ax.set_ylabel("F1-Score")

plt.show()
